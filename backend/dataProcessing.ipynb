# %%
import os
import glob
import json
import re

import chromadb
from chromadb.config import Settings
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.docstore.document import Document
from langchain.vectorstores import Chroma

# %%
# !pip install "langchain==0.2.6"
# !pip install "ibm-watsonx-ai==1.0.10"
# !pip install "langchain_ibm==0.1.8"
# !pip install "langchain_community==0.2.6"
# !pip install "sentence-transformers==3.0.1"
# !pip install "chromadb==0.5.3"
# !pip install "pydantic==2.8.2"
# !pip install "langchain-huggingface==0.0.3"
# !pip install "python-dotenv==1.0.1"
# Out:
# Requirement already satisfied: langchain==0.2.6 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (0.2.6)
# Requirement already satisfied: PyYAML>=5.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (3.11.12)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain==0.2.6) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.6) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic<3,>=1->langchain==0.2.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic<3,>=1->langchain==0.2.6) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests<3,>=2->langchain==0.2.6) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests<3,>=2->langchain==0.2.6) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests<3,>=2->langchain==0.2.6) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests<3,>=2->langchain==0.2.6) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.6) (3.1.1)
# Requirement already satisfied: anyio in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain==0.2.6) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.6) (1.3.1)
# Requirement already satisfied: ibm-watsonx-ai==1.0.10 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (1.0.10)
# Requirement already satisfied: requests in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai==1.0.10) (2.32.2)
# Requirement already satisfied: urllib3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai==1.0.10) (2.3.0)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai==1.0.10) (2.1.4)
# Requirement already satisfied: certifi in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai==1.0.10) (2025.1.31)
# Requirement already satisfied: lomond in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai==1.0.10) (0.3.3)
# Requirement already satisfied: tabulate in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai==1.0.10) (0.9.0)
# Requirement already satisfied: packaging in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai==1.0.10) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai==1.0.10) (2.13.6)
# Requirement already satisfied: importlib-metadata in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai==1.0.10) (8.5.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.0.10) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.0.10) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.0.10) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.0.10) (2.9.0.post0)
# Requirement already satisfied: numpy<2,>=1.26.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.0.10) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.0.10) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.0.10) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->ibm-watsonx-ai==1.0.10) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->ibm-watsonx-ai==1.0.10) (3.10)
# Requirement already satisfied: zipp>=3.20 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from importlib-metadata->ibm-watsonx-ai==1.0.10) (3.21.0)
# Requirement already satisfied: six>=1.10.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from lomond->ibm-watsonx-ai==1.0.10) (1.17.0)
# Requirement already satisfied: langchain_ibm==0.1.8 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (0.1.8)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.0.8 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_ibm==0.1.8) (1.0.10)
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_ibm==0.1.8) (0.2.43)
# Requirement already satisfied: requests in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.32.2)
# Requirement already satisfied: urllib3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.3.0)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.1.4)
# Requirement already satisfied: certifi in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2025.1.31)
# Requirement already satisfied: lomond in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (0.3.3)
# Requirement already satisfied: tabulate in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (0.9.0)
# Requirement already satisfied: packaging in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.13.6)
# Requirement already satisfied: importlib-metadata in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (8.5.0)
# Requirement already satisfied: PyYAML>=5.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (0.1.147)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (4.12.2)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2.9.0.post0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (1.0.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (2025.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (3.10)
# Requirement already satisfied: zipp>=3.20 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from importlib-metadata->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (3.21.0)
# Requirement already satisfied: six>=1.10.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from lomond->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain_ibm==0.1.8) (1.17.0)
# Requirement already satisfied: anyio in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain_ibm==0.1.8) (1.3.1)
# Requirement already satisfied: langchain_community==0.2.6 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (0.2.6)
# Requirement already satisfied: PyYAML>=5.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (3.11.12)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.6 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (0.2.6)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain_community==0.2.6) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.2.6) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.2.6) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.2.6) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain<0.3.0,>=0.2.6->langchain_community==0.2.6) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain<0.3.0,>=0.2.6->langchain_community==0.2.6) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_community==0.2.6) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_community==0.2.6) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_community==0.2.6) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests<3,>=2->langchain_community==0.2.6) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests<3,>=2->langchain_community==0.2.6) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests<3,>=2->langchain_community==0.2.6) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests<3,>=2->langchain_community==0.2.6) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain_community==0.2.6) (3.1.1)
# Requirement already satisfied: anyio in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain_community==0.2.6) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain_community==0.2.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain_community==0.2.6) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community==0.2.6) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.2.6) (1.3.1)
# Requirement already satisfied: sentence-transformers==3.0.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers==3.0.1) (4.48.2)
# Requirement already satisfied: tqdm in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers==3.0.1) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers==3.0.1) (2.6.0)
# Requirement already satisfied: numpy in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers==3.0.1) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers==3.0.1) (1.6.1)
# Requirement already satisfied: scipy in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers==3.0.1) (1.15.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers==3.0.1) (0.28.1)
# Requirement already satisfied: Pillow in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers==3.0.1) (11.1.0)
# Requirement already satisfied: filelock in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2025.2.0)
# Requirement already satisfied: packaging>=20.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (6.0.2)
# Requirement already satisfied: requests in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2.32.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (4.12.2)
# Requirement already satisfied: networkx in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.2.0)
# Requirement already satisfied: setuptools in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers==3.0.1) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.1) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.1) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.1) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from scikit-learn->sentence-transformers==3.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from scikit-learn->sentence-transformers==3.0.1) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2025.1.31)
# Collecting chromadb==0.5.3
#   Using cached chromadb-0.5.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: build>=1.0.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (1.2.2.post1)
# Requirement already satisfied: requests>=2.28 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (2.32.2)
# Requirement already satisfied: pydantic>=1.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (2.8.2)
# Collecting chroma-hnswlib==0.7.3 (from chromadb==0.5.3)
#   Using cached chroma-hnswlib-0.7.3.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: fastapi>=0.95.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (0.115.8)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.34.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (3.11.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (32.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from chromadb==0.5.3) (0.28.1)
# Requirement already satisfied: packaging>=19.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from build>=1.0.3->chromadb==0.5.3) (24.2)
# Requirement already satisfied: pyproject_hooks in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from build>=1.0.3->chromadb==0.5.3) (1.2.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from fastapi>=0.95.2->chromadb==0.5.3) (0.45.3)
# Requirement already satisfied: anyio in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (4.8.0)
# Requirement already satisfied: certifi in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (1.0.7)
# Requirement already satisfied: idna in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==0.5.3) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (0.9)
# Requirement already satisfied: coloredlogs in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (25.1.24)
# Requirement already satisfied: protobuf in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (5.29.3)
# Requirement already satisfied: sympy in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.3) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.3) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-instrumentation==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from posthog>=2.4.0->chromadb==0.5.3) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from posthog>=2.4.0->chromadb==0.5.3) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic>=1.9->chromadb==0.5.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic>=1.9->chromadb==0.5.3) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests>=2.28->chromadb==0.5.3) (3.4.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from tokenizers>=0.13.2->chromadb==0.5.3) (0.28.1)
# Requirement already satisfied: click>=8.0.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from typer>=0.9.0->chromadb==0.5.3) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from typer>=0.9.0->chromadb==0.5.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from typer>=0.9.0->chromadb==0.5.3) (13.9.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (14.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (4.9)
# Requirement already satisfied: filelock in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.3) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.3) (2025.2.0)
# Requirement already satisfied: zipp>=3.20 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.5.3) (3.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (2.19.1)
# Requirement already satisfied: sniffio>=1.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb==0.5.3) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.3) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.3) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (0.6.1)
# Using cached chromadb-0.5.3-py3-none-any.whl (559 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [63 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       creating tmp
#       g++ -fno-strict-overflow -Wsign-compare -DDYNAMIC_ANNOTATIONS_ENABLED=1 -DNDEBUG -O2 -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fstack-protector-strong -m64 -march=x86-64-v2 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -O2 -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fstack-protector-strong -m64 -march=x86-64-v2 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -O2 -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fstack-protector-strong -m64 -march=x86-64-v2 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fPIC -I/home/ibmuser03/.venv/include -I/usr/include/python3.12 -c /tmp/tmp3oc8bxr1.cpp -o tmp/tmp3oc8bxr1.o -std=c++14
#       g++ -fno-strict-overflow -Wsign-compare -DDYNAMIC_ANNOTATIONS_ENABLED=1 -DNDEBUG -O2 -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fstack-protector-strong -m64 -march=x86-64-v2 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -O2 -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fstack-protector-strong -m64 -march=x86-64-v2 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -O2 -fexceptions -g -grecord-gcc-switches -pipe -Wall -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fstack-protector-strong -m64 -march=x86-64-v2 -mtune=generic -fasynchronous-unwind-tables -fstack-clash-protection -fcf-protection -fPIC -I/home/ibmuser03/.venv/include -I/usr/include/python3.12 -c /tmp/tmpwmfk58wm.cpp -o tmp/tmpwmfk58wm.o -std=c++11
#       Traceback (most recent call last):
#         File "/home/ibmuser03/.venv/lib64/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#         File "/home/ibmuser03/.venv/lib64/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/ibmuser03/.venv/lib64/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 280, in build_wheel
#           return _build_backend().build_wheel(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 438, in build_wheel
#           return _build(['bdist_wheel', '--dist-info-dir', str(metadata_directory)])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 426, in _build
#           return self._build_with_temp_dir(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 407, in _build_with_temp_dir
#           self.run_setup()
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 320, in run_setup
#           exec(code, locals())
#         File "<string>", line 115, in <module>
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/__init__.py", line 117, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/core.py", line 186, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/core.py", line 202, in run_commands
#           dist.run_commands()
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 983, in run_commands
#           self.run_command(cmd)
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/dist.py", line 999, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 1002, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/command/bdist_wheel.py", line 379, in run
#           self.run_command("build")
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/cmd.py", line 339, in run_command
#           self.distribution.run_command(command)
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/dist.py", line 999, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 1002, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/command/build.py", line 136, in run
#           self.run_command(cmd_name)
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/cmd.py", line 339, in run_command
#           self.distribution.run_command(command)
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/dist.py", line 999, in run_command
#           super().run_command(command)
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 1002, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/command/build_ext.py", line 99, in run
#           _build_ext.run(self)
#         File "/tmp/pip-build-env-hkannave/overlay/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py", line 365, in run
#           self.build_extensions()
#         File "<string>", line 102, in build_extensions
#         File "<string>", line 69, in cpp_flag
#       RuntimeError: Unsupported compiler -- at least C++11 support is needed!
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# Failed to build chroma-hnswlib
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)
# Requirement already satisfied: pydantic==2.8.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (2.8.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic==2.8.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic==2.8.2) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic==2.8.2) (4.12.2)
# Requirement already satisfied: langchain-huggingface==0.0.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (0.0.3)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-huggingface==0.0.3) (0.28.1)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-huggingface==0.0.3) (0.2.43)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-huggingface==0.0.3) (3.0.1)
# Requirement already satisfied: tokenizers>=0.19.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-huggingface==0.0.3) (0.21.0)
# Requirement already satisfied: transformers>=4.39.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-huggingface==0.0.3) (4.48.2)
# Requirement already satisfied: filelock in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (2025.2.0)
# Requirement already satisfied: packaging>=20.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (6.0.2)
# Requirement already satisfied: requests in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (0.1.147)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (8.5.0)
# Requirement already satisfied: torch>=1.11.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (2.6.0)
# Requirement already satisfied: numpy in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.6.1)
# Requirement already satisfied: scipy in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.15.1)
# Requirement already satisfied: Pillow in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (11.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from transformers>=4.39.0->langchain-huggingface==0.0.3) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from transformers>=4.39.0->langchain-huggingface==0.0.3) (0.5.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface==0.0.3) (2025.1.31)
# Requirement already satisfied: networkx in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.2.0)
# Requirement already satisfied: setuptools in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.5.0)
# Requirement already satisfied: anyio in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface==0.0.3) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-huggingface==0.0.3) (1.3.1)
# Requirement already satisfied: python-dotenv==1.0.1 in /home/ibmuser03/.venv/lib64/python3.12/site-packages (1.0.1)

# %%
import os
from dotenv import load_dotenv
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA

from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import DecodingMethods
from langchain.llms import WatsonxLLM

# %%
# !pip install chromadb|
# !pip install pysqlite3-binary

__import__('pysqlite3')
import sys
sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')
# Out:
# Requirement already satisfied: pysqlite3-binary in /home/ibmuser03/.venv/lib64/python3.12/site-packages (0.5.4)

# %%
# 함수 정의

def clean_text(text):
    """
    text가 문자열이 아닐 경우(예: list, dict) 등을 처리해주는 버전
    """
    if isinstance(text, list):
        # 리스트이면 각 항목을 문자열로 변환 후 공백으로 join
        text = " ".join(str(t) for t in text)
    elif not isinstance(text, str):
        text = str(text)
    
    text = text.replace("\r", " ").replace("\t", " ")
    text = re.sub(r"\s+", " ", text)
    text = text.strip()
    return text

def _extract_table_item(table_dict: dict, results: list):
    """
    '별표단위'의 한 요소(별표번호, 별표제목, 별표내용 등)를 줄 단위로 전처리하여 results에 추가
    """
    table_num = table_dict.get("별표번호", "")
    table_num = clean_text(table_num)
    
    table_title = table_dict.get("별표제목", "")
    table_title = clean_text(table_title)
    
    if table_num or table_title:
        results.append(f"(별표번호) {table_num} (별표제목) {table_title}")

    table_contents = table_dict.get("별표내용", [])
    if isinstance(table_contents, list):
        for paragraph_list in table_contents:
            if isinstance(paragraph_list, list):
                for line in paragraph_list:
                    if isinstance(line, str):
                        txt = clean_text(line)
                        if txt:
                            results.append(txt)

def extract_text_from_law_json(json_data: dict) -> list:
    results = []
    law = json_data.get("법령", {})

    # (1) 법령명
    law_name = law.get("기본정보", {}).get("법령명_한글", "")
    results.append(f"[{clean_text(law_name)}]")

    # (2) 부칙
    sup_provisions = law.get("부칙", {}).get("부칙단위", [])
    for sup_provision in sup_provisions:
        content = sup_provision.get("부칙내용", [])
        for paragraph_list in content:  # 2차원 리스트
            cleaned_line = []
            for line in paragraph_list:
                line = clean_text(line)
                if line:
                    cleaned_line.append(line)
            merged = "".join(cleaned_line)
            if merged:
                results.append(merged)

    # (3) 조문
    provisions = law.get("조문", {}).get("조문단위", [])
    for provision in provisions:
        article_text = provision.get("조문내용", "")
        article_text = clean_text(article_text)
        if article_text:
            results.append(article_text)

        # 항(단일 dict or list)
        if "항" in provision:
            if isinstance(provision["항"], dict):
                ho_list = provision["항"].get("호", [])
                if isinstance(ho_list, list):
                    for ho_item in ho_list:
                        ho_text = ho_item.get("호내용", "")
                        ho_text = clean_text(ho_text)
                        if ho_text:
                            results.append(ho_text)
            elif isinstance(provision["항"], list):
                for paragraph_item in provision["항"]:
                    if isinstance(paragraph_item, dict):
                        para_text = paragraph_item.get("항내용", "")
                        para_text = clean_text(para_text)
                        if para_text:
                            results.append(para_text)

                        if "호" in paragraph_item:
                            ho_list = paragraph_item["호"]
                            if isinstance(ho_list, list):
                                for ho_item in ho_list:
                                    ho_text = ho_item.get("호내용", "")
                                    ho_text = clean_text(ho_text)
                                    if ho_text:
                                        results.append(ho_text)

    # (4) 별표
    if "별표" in law:
        annex_container = law["별표"]
        if isinstance(annex_container, dict):
            table_list = annex_container.get("별표단위", [])
            if isinstance(table_list, list):
                for table_item in table_list:
                    if isinstance(table_item, dict):
                        _extract_table_item(table_item, results)

    return results

def chunk_text(text_list: list, max_chunk_size: int = 500) -> list:
    """
    긴 텍스트를 일정 크기(max_chunk_size)로 분할
    """
    chunks = []
    for text in text_list:
        if len(text) <= max_chunk_size:
            chunks.append(text)
        else:
            start = 0
            while start < len(text):
                end = start + max_chunk_size
                chunks.append(text[start:end])
                start = end
    return chunks

# %%
# (1) JSON 파일 로드 & 텍스트 추출
all_docs = []
all_metadatas = []

json_files = glob.glob(os.path.join('laws', "*.json"))
print(f"Found {len(json_files)} JSON files")

for file_path in json_files:
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    # 전처리
    extracted_texts = extract_text_from_law_json(data)
    # 청크 분할
    chunks = chunk_text(extracted_texts, max_chunk_size=500)

    # 문서/메타데이터 수집
    for c in chunks:
        all_docs.append(c)
        # 메타데이터: 파일명 or 조문번호 등 필요한 항목
        all_metadatas.append({"source_file": os.path.basename(file_path)})

print(f"Total {len(all_docs)} chunks extracted.")

# (2) 임베딩 모델 & Chroma 생성
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"  # 예시 임베딩 모델
)

# Chroma 벡터스토어 생성
# 이미 chroma_db 폴더가 있으면 추가로 병합하려면 로우레벨 API 사용하거나
# 새로 만들 경우 아래처럼 from_texts 사용
persist_directory = 'chroma_db'
vectorstore = Chroma.from_texts(
    texts=all_docs,
    embedding=embedding_model,
    metadatas=all_metadatas,
    persist_directory=persist_directory
)
# DB를 디스크에 저장
vectorstore.persist()
print(f"Chroma DB stored at: {persist_directory}")
# Out:
# Found 13 JSON files
# Total 13620 chunks extracted.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 34
#      30 # Chroma 벡터스토어 생성
#      31 # 이미 chroma_db 폴더가 있으면 추가로 병합하려면 로우레벨 API 사용하거나
#      32 # 새로 만들 경우 아래처럼 from_texts 사용
#      33 persist_directory = 'chroma_db'
# ---> 34 vectorstore = Chroma.from_texts(
#      35     texts=all_docs,
#      36     embedding=embedding_model,
#      37     metadatas=all_metadatas,
#      38     persist_directory=persist_directory
#      39 )
#      40 # DB를 디스크에 저장
#      41 vectorstore.persist()
#
# File ~/.venv/lib64/python3.12/site-packages/langchain_community/vectorstores/chroma.py:726, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     693 @classmethod
#     694 def from_texts(
#     695     cls: Type[Chroma],
#    (...)
#     705     **kwargs: Any,
#     706 ) -> Chroma:
#     707     """Create a Chroma vectorstore from a raw documents.
#     708
#     709     If a persist_directory is specified, the collection will be persisted there.
#    (...)
#     724         Chroma: Chroma vectorstore.
#     725     """
# --> 726     chroma_collection = cls(
#     727         collection_name=collection_name,
#     728         embedding_function=embedding,
#     729         persist_directory=persist_directory,
#     730         client_settings=client_settings,
#     731         client=client,
#     732         collection_metadata=collection_metadata,
#     733         **kwargs,
#     734     )
#     735     if ids is None:
#     736         ids = [str(uuid.uuid4()) for _ in texts]
#
# File ~/.venv/lib64/python3.12/site-packages/langchain_community/vectorstores/chroma.py:116, in Chroma.__init__(self, collection_name, embedding_function, persist_directory, client_settings, collection_metadata, client, relevance_score_fn)
#     112         _client_settings = chromadb.config.Settings(
#     113             chroma_db_impl="duckdb+parquet",
#     114         )
#     115     else:
# --> 116         _client_settings = chromadb.config.Settings(is_persistent=True)
#     117     _client_settings.persist_directory = persist_directory
#     118 else:
#
# AttributeError: module 'chromadb' has no attribute 'config'

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = Chroma(
    embedding_function=embedding_model,
    persist_directory="chroma_db"
)

query = "어린이 보호구역 속도 위반 과태료는 얼마인가?"
docs = vectorstore.similarity_search(query, k=3)
for i, doc in enumerate(docs, start=1):
    print(f"[DOC {i}] {doc.page_content}")
    print(f"Meta: {doc.metadata}")
    print("------------------")
